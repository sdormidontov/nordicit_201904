# %%
import pymysql
import csv

# %%
db_conn = pymysql.connect(host="139.162.170.240", 
                          user='nordic', 
                          passwd='password0', 
                          db='nordicDB')

cursor = db_conn.cursor()

# %%
FILE_CSV = 'train.csv'

# %%
with open(FILE_CSV) as f:
    f_read = csv.reader(f)
    for row in f_read:
        print(row)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# ['1', '0', '3', 'Braund, Mr. Owen Harris', 'male', '22', '1', '0', 'A/5 21171', '7.25', '', 'S']
# ['2', '1', '1', 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'female', '38', '1', '0', 'PC 17599', '71.2833', 'C85', 'C']
# ['3', '1', '3', 'Heikkinen, Miss. Laina', 'female', '26', '0', '0', 'STON/O2. 3101282', '7.925', '', 'S']
# ['4', '1', '1', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'female', '35', '1', '0', '113803', '53.1', 'C123', 'S']
# ['5', '0', '3', 'Allen, Mr. William Henry', 'male', '35', '0', '0', '373450', '8.05', '', 'S']
# ['6', '0', '3', 'Moran, Mr. James', 'male', '', '0', '0', '330877', '8.4583', '', 'Q']
# ['7', '0', '1', 'McCarthy, Mr. Timothy J', 'male', '54', '0', '0', '17463', '51.8625', 'E46', 'S']
# ['8', '0', '3', 'Palsson, Master. Gosta Leonard', 'male', '2', '3', '1', '349909', '21.075', '', 'S']
# ...

# %%
query = """
   CREATE TABLE train_d
    (
         PassengerId INT PRIMARY KEY, 
         Survived INT NOT NULL, 
         Pclass INT NOT NULL,
         Name TEXT NOT NULL, 
         Sex TEXT NOT NULL, 
         Age FLOAT, 
         SibSp INT NOT NULL, 
         Parch INT NOT NULL, 
         Ticket TEXT NOT NULL, 
         Fare FLOAT, 
         Cabin TEXT, 
         Embarked TEXT
    );

   
"""

cursor.execute(query)
db_conn.commit()

# %%
query = """
INSERT INTO train_d VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

with open(FILE_CSV) as f:
    file = csv.reader(f)
    for i , row in enumerate(file):
        if i == 0:
            continue
        for j, r in enumerate(row):
            if row[j] == '':
                row[j] = None
        print(row)
        cursor.execute(query, row)    
db_conn.commit()
# Out:
# ['1', '0', '3', 'Braund, Mr. Owen Harris', 'male', '22', '1', '0', 'A/5 21171', '7.25', None, 'S']
# ['2', '1', '1', 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'female', '38', '1', '0', 'PC 17599', '71.2833', 'C85', 'C']
# ['3', '1', '3', 'Heikkinen, Miss. Laina', 'female', '26', '0', '0', 'STON/O2. 3101282', '7.925', None, 'S']
# ['4', '1', '1', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'female', '35', '1', '0', '113803', '53.1', 'C123', 'S']
# ['5', '0', '3', 'Allen, Mr. William Henry', 'male', '35', '0', '0', '373450', '8.05', None, 'S']
# ['6', '0', '3', 'Moran, Mr. James', 'male', None, '0', '0', '330877', '8.4583', None, 'Q']
# ['7', '0', '1', 'McCarthy, Mr. Timothy J', 'male', '54', '0', '0', '17463', '51.8625', 'E46', 'S']
# ['8', '0', '3', 'Palsson, Master. Gosta Leonard', 'male', '2', '3', '1', '349909', '21.075', None, 'S']
# ['9', '1', '3', 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', 'female', '27', '0', '2', '347742', '11.1333', None, 'S']
# ...

# %%
db_conn.rollback()

# %%
query_select_all = """
SELECT *
from train_d
"""

cursor.execute(query_select_all)
cursor.fetchall()
# Out:
# ((1,
#   0,
#   3,
#   'Braund, Mr. Owen Harris',
#   'male',
#   22.0,
#   1,
#   0,
#   'A/5 21171',
#   7.25,
#   None,
#   'S'),
#  (2,
#   1,
#   1,
#   'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#   'female',
#   38.0,
#   1,
#   0,
#   'PC 17599',
#   71.2833,
#   'C85',
#   'C'),
#  (3,
#   1,
#   3,
#   'Heikkinen, Miss. Laina',
#   'female',
#   26.0,
#   0,
#   0,
#   'STON/O2. 3101282',
#   7.925,
#   None,
#   'S'),
#  (4,
#   1,
#   1,
#   'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#   'female',
#   35.0,
#   1,
#   0,
#   '113803',
#   53.1,
#   'C123',
#   'S'),
#  (5,
#   0,
#   3,
#   'Allen, Mr. William Henry',
#   'male',
#   35.0,
#   0,
#   0,
#   '373450',
#   8.05,
#   None,
#   'S'),
#  (6,
#   0,
#   3,
#   'Moran, Mr. James',
#   'male',
#   None,
#   0,
#   0,
#   '330877',
#   8.4583,
#   None,
#   'Q'),
#  (7,
#   0,
#   1,
#   'McCarthy, Mr. Timothy J',
#   'male',
#   54.0,
#   0,
#   0,
#   '17463',
#   51.8625,
#   'E46',
#   'S'),
# ...

# %%
query_select_all = """
SELECT *
from train_d
where Age = ()
"""

cursor.execute(query_select_all)
cursor.fetchall()

# %%
import numpy as np

# %%
mtx = np.array(
    [['0.0', '1.0'],
    ['', ''],
    ['2.0', '2.0']]
)

# %%
mtx[mtx[:, 0] != '']
# Out:
# array([['0.0', '1.0'],
#        ['2.0', '2.0']], dtype='<U3')

# %% [markdown]
# ### библиотека Requests

# %%
import requests

# %%
dir(requests) # список всех функций
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'cryptography_version',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
#  'patch',
#  'post',
#  'put',
# ...

# %%
# запрос состоит из урла и тела 
# get запрос - в строке браузера
# post запрос - передается внутренними средствами браузера через код

# %%
url = 'https://yandex.ru/search/'

params = {
    'text':'python',
    'lr':'213'
}

r = requests.get(url, params=params) # r - это response!!!

# %%
r.url
# Out:
# 'https://yandex.ru/search/?text=python&lr=213'

# %%
r.text[:1000]
# Out:
# '<!DOCTYPE html><html class=i-ua_js_no lang=ru><meta charset=utf-8><meta http-equiv=X-UA-Compatible content="IE=edge"><title>Яндекс</title><script nonce=4937>document.documentElement.className="i-ua_js_yes i-ua_svg_yes";(screen.deviceXDPI&&screen.logicalXDPI&&screen.deviceXDPI/screen.logicalXDPI||window.devicePixelRatio)>1&&(document.documentElement.className+=" i-ua_retina_yes");</script><link rel=search title="Яндекс" type="application/opensearchdescription+xml" href="/search/opensearch.xml"><meta name=referrer content=always><style nonce=4937 data-role=css data-stylesheet=header>body{margin:0}.b-page__body{margin:0;color:#000;background:#fff;height:100%;padding:0;font-family:Arial,Helvetica,sans-serif;font-size:13px;line-height:1.154}.i-ua_platform_ios.b-page__body{-webkit-tap-highlight-color:rgba(0,0,0,0);cursor:auto}html{height:100%}.b-page.b-page_js_inited.b-page_overflow_hidden,.b-page_initial-scroll_yes.b-page_js_inited.b-page_overflow_yes{overflow:hidden}.b-page_offset_top{p
# ...

# %%
r.status_code
# Out:
# 200

# %%
r.ok
# Out:
# True

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.request
# Out:
# <PreparedRequest [GET]>

# %%
url = 'https://avatars.mds.yandex.net/get-pdb/202366/8d1cf942-5ee8-4745-9073-31cef5e175b5/s1200'

r = requests.get(url)

# %%
r.text[:1000]
# Out:
# '����\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00��\x00C\x00\x05\x03\x04\x04\x04\x03\x05\x04\x04\x04\x05\x05\x05\x06\x07\x0c\x08\x07\x07\x07\x07\x0f\x0b\x0b\t\x0c\x11\x0f\x12\x12\x11\x0f\x11\x11\x13\x16\x1c\x17\x13\x14\x1a\x15\x11\x11\x18!\x18\x1a\x1d\x1d\x1f\x1f\x1f\x13\x17"$"\x1e$\x1c\x1e\x1f\x1e��\x00C��\x00\x11\x08\x02�\x04�\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01��\x00\x1c\x00\x00\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x01\x04\x05\x00\x06\x07\x08��\x00F\x10\x00\x02\x01\x03\x03\x02\x04\x04\x04\x05\x03\x04\x01\x02\x02\x0b\x01\x02\x03\x00\x11!\x04\x121\x05A\x13"Qa\x06q��\x142��#B���\x07R�\x153b�$\x08Cr%4�DS��\x16c\x17����\x00\x1b\x01\x00\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
with open('lion.jpg', 'wb') as f:
    f.write(r.content)

# %%
lst = [
    'https://img.fonwall.ru/o/51/lev_griva_valun_zapovednik.JPG',
    'http://luxfon.com/pic/201407/1920x1080/luxfon.com-27942.jpg',
    'https://s1.1zoom.ru/big3/985/Lions_457331.jpg'
]

for i, url in enumerate(lst):
    r = requests.get(url)
    with open('file {0}.jpg'.format(i), 'wb') as f:
        f.write(r.content)

# %%
r.headers.get('content-type')
# Out:
# 'image/jpeg'

# %%
url = 'https://eda.yandex.ru'
r = requests.get(url)
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='eda_web', value='%7B%22app%22%3A%7B%22lat%22%3Anull%2C%22lon%22%3Anull%2C%22ipLat%22%3Anull%2C%22ipLon%22%3Anull%2C%22regionId%22%3Anull%2C%22deliveryTime%22%3Anull%2C%22xDeviceId%22%3Anull%2C%22appBannerShown%22%3Afalse%2C%22ab%22%3A%7B%7D%7D%7D', port=None, port_specified=False, domain='eda.yandex', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1591813743, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='eda_web_render_id', value='jws52ztv-xydvnr6x52-zfyd13hvtb8-p3cs39o5wq', port=None, port_specified=False, domain='eda.yandex', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)]>

# %%
dict(r.cookies)
# Out:
# {'eda_web': '%7B%22app%22%3A%7B%22lat%22%3Anull%2C%22lon%22%3Anull%2C%22ipLat%22%3Anull%2C%22ipLon%22%3Anull%2C%22regionId%22%3Anull%2C%22deliveryTime%22%3Anull%2C%22xDeviceId%22%3Anull%2C%22appBannerShown%22%3Afalse%2C%22ab%22%3A%7B%7D%7D%7D',
#  'eda_web_render_id': 'jws52ztv-xydvnr6x52-zfyd13hvtb8-p3cs39o5wq'}

# %%
url = 'https://yandex.ru/search/'

dct = {
    'text':'python 3',
    'lr':'213'
}

r = requests.get(url, params=dct)

# %%
r.url
# Out:
# 'https://yandex.ru/search/?text=python+3&lr=213'

# %%
r.headers.get('Content-type')
# Out:
# 'text/html; charset=utf-8'

# %%
r = requests.get(url, params = dct)

ct = r.headers.get('Content-Type').split(';')[0].split('/')
encoding = r.headers.get('Content-Type').split(';')[1].split('=')[1]

if r.ok and ct[0] == 'text':
    with open('{0}.{1}'.format(dct['text'], ct[1]), 'w', encoding=encoding) as f:
        f.write(r.text)
